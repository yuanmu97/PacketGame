# %%
import sys
sys.path.append("../src")
from contextual_tf import build_conv1d_twoview, build_ensemble_threeview

# %%
m = build_conv1d_twoview(inp_len1=5, inp_len2=5, conv_units=[32, 32])
m.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# View1-Indepdendent (InputLayer) [(None, None, 5)]    0
# __________________________________________________________________________________________________
# View2-Predicted (InputLayer)    [(None, None, 5)]    0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, None, 32)     192         View1-Indepdendent[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, None, 32)     192         View2-Predicted[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, None, 32)     1056        conv1d[0][0]
# ...

# %%
m = build_ensemble_threeview(inp_len1=5, inp_len2=5, inp_len3=1, conv_units=[32, 32], dense_unit=128)
m.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# View1-Indepdendent (InputLayer) [(None, None, 5)]    0
# __________________________________________________________________________________________________
# View2-Predicted (InputLayer)    [(None, None, 5)]    0
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, None, 32)     192         View1-Indepdendent[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, None, 32)     192         View2-Predicted[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, None, 32)     1056        conv1d_4[0][0]
# ...
